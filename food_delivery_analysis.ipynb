# %% [markdown]
# # Food Delivery Data Analysis
#
# This notebook contains analysis for the food delivery hackathon dataset.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("final_food_delivery_dataset.csv")

df.head()

# %% [markdown]
# ## Example Analysis
# Gold vs Regular Membership Orders

# %%
df['membership'].value_counts()
